# %%
import pandas as pd
import os

# %%
import seaborn as sns
import matplotlib.pyplot as plt #graafik çizme - charts
# %matplotlib inline 
import numpy as np #sahte veri üretmemizi sağlar,MATEMATİK,VECTÖRLER,TÜREV,İNTREGRAL,DİFERANSİYEL DENKLEMLER,İSTATİSTİK

# %%
dataframes=[] #dataframe'leri saklmak için boş liste oluşturur

path='/content/drive/MyDrive/Coffee/coffee_data'#CSV dosyalarını içeren dizinin yolunu belirtir

# dizindeki tüm dosyaları dolaşır
for filename in os.listdir(path):
    # dosyanın CSV dosyası olup olmadığını kontrol eder
    if filename.endswith('.csv'):
      #dosyayı pandas kullanarak okur
       df=pd.read_csv(os.path.join(path,filename))
       #listeyi dataframe ekler
       dataframes.append(df)
#tüm dataframeleri birleştirir.
result=pd.concat(dataframes)

# %%
result=pd.concat(dataframes, axis=1)

# %% [markdown]
# ## EDA

# %%
result.head()#ilk beş satırı verir.
# Out:
#                             Country      Coffee type    1990/91    1991/92  \
# 0                            Angola  Robusta/Arabica    1200000    1800000
# 1  Bolivia (Plurinational State of)          Arabica    1500000    1620000
# 2                            Brazil  Arabica/Robusta  492000000  510000000
# 3                           Burundi  Arabica/Robusta     120000      96000
# 4                           Ecuador  Arabica/Robusta   21000000   21000000
#
#      1992/93    1993/94    1994/95    1995/96    1996/97    1997/98  ...  \
# 0    2100000    1200000    1500000     600000    1200000    2400000  ...
# 1    1650000    1710000    1770000    1830000    1890000    1950000  ...
# 2  534000000  546000000  558000000  606000000  660000000  690000000  ...
# 3     102000     114600     120000     120000     120000     120000  ...
# 4   21000000   21000000   21000000   21000000   18000000   18000000  ...
#
#         2011/12       2012/13       2013/14       2014/15       2015/16  \
# ...

# %%
result.tail()#son beş satırı gösterir.
# Out:
#               Country      Coffee type   1990/91   1991/92   1992/93  \
# 50  Trinidad & Tobago          Robusta    480000    690000    600000
# 51             Uganda  Robusta/Arabica   4200000   4500000   4500000
# 52          Venezuela          Arabica  46943400  48928800  50998200
# 53           Viet Nam  Robusta/Arabica   9000000  13800000  15000000
# 54              Yemen          Arabica         0         0         0
#
#      1993/94   1994/95   1995/96   1996/97   1997/98  ...       2011/12  \
# 50    600000    840000    840000    840000    840000  ...  6.600000e+05
# 51   4500000   4800000   4800000   4800000   6071400  ...  1.869000e+08
# 52  53155800  55404000  57747600  60190800  62736599  ...  5.412000e+07
# 53  16020000  16020000  16910700  17850960  18843480  ...  1.590000e+09
# 54         0         0         0         0         0  ...  1.110000e+07
#
#          2012/13       2013/14       2014/15       2015/16       2016/17  \
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Columns: 226 entries, Country to Total_production
# dtypes: float64(155), int64(62), object(9)
# memory usage: 97.2+ KB

# %%
result.corr()
# Out:
#                    1990/91   1991/92   1992/93   1993/94   1994/95   1995/96  \
# 1990/91           1.000000  0.999421  0.999558  0.998407  0.997634  0.997594
# 1991/92           0.999421  1.000000  0.999871  0.999527  0.999112  0.998862
# 1992/93           0.999558  0.999871  1.000000  0.999516  0.998999  0.998917
# 1993/94           0.998407  0.999527  0.999516  1.000000  0.999715  0.999475
# 1994/95           0.997634  0.999112  0.998999  0.999715  1.000000  0.999692
# ...                    ...       ...       ...       ...       ...       ...
# 2016/17           0.879846  0.886165  0.885851  0.888095  0.888669  0.886191
# 2017/18           0.831573  0.838256  0.838166  0.840114  0.840585  0.838232
# 2018/19           0.890582  0.896746  0.896748  0.898988  0.899410  0.898060
# 2019/20           0.870727  0.877095  0.877004  0.879421  0.879927  0.878091
# Total_production  0.917859  0.922081  0.921960  0.923219  0.923428  0.921279
#
# ...

# %%
result.isnull().sum()#verilerin boşları gösterir
# Out:
# Country             0
# Coffee type         0
# 1990/91             0
# 1991/92             0
# 1992/93             0
#                    ..
# 2016/17             0
# 2017/18             0
# 2018/19             0
# 2019/20             0
# Total_production    0
# Length: 226, dtype: int64

# %%
result.sample(5)#rastgele veri gösterir.
# Out:
#                              Country      Coffee type   1990/91   1991/92  \
# 39  Lao People's Democratic Republic          Robusta         0         0
# 19                          Tanzania  Arabica/Robusta    240000    210000
# 5                          Indonesia  Robusta/Arabica  74520000  76800000
# 53                          Viet Nam  Robusta/Arabica   9000000  13800000
# 4                            Ecuador  Arabica/Robusta  21000000  21000000
#
#      1992/93   1993/94   1994/95   1995/96   1996/97   1997/98  ...  \
# 39         0         0         0         0         0         0  ...
# 19   1152000   1050000   1050000    816000    996000   1020000  ...
# 5   79140000  81540000  84000000  86580000  89160000  91920000  ...
# 53  15000000  16020000  16020000  16910700  17850960  18843480  ...
# 4   21000000  21000000  21000000  21000000  18000000  18000000  ...
#
#          2011/12       2012/13       2013/14       2014/15       2015/16  \
# ...

# %%
result.describe()#istatikseli gösterir
# Out:
#             1990/91       1991/92       1992/93       1993/94       1994/95  \
# count  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   2.128278e+07  2.206701e+07  2.285613e+07  2.301590e+07  2.330200e+07
# std    6.810062e+07  7.032839e+07  7.363077e+07  7.511769e+07  7.679945e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.800000e+05  1.800000e+05  1.800000e+05  2.400000e+05  2.400000e+05
# 50%    2.040000e+06  3.000000e+06  3.000000e+06  2.400000e+06  3.000000e+06
# 75%    1.299000e+07  1.671300e+07  1.650000e+07  1.731000e+07  1.650000e+07
# max    4.920000e+08  5.100000e+08  5.340000e+08  5.460000e+08  5.580000e+08
#
#             1995/96       1996/97       1997/98       1998/99       1999/00  \
# count  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   2.465735e+07  2.565010e+07  2.647750e+07  2.739992e+07  2.808131e+07
# ...

# %%
result.shape#satır ve sütun sayılarını gösterir.
# Out:
# (55, 226)

# %%
plt.figure(figsize=(12,16))
plt.title('1990-1991 years')
sns.countplot(df['1990/91'],hue=df['Coffee type'])#hangi ürünler en çok satılmış gösterir
plt.xticks(rotation=90);
plt.legend(loc=4) #renklerin ne anlama geldiğini belirten kutucuğun grafik üzerine konumunu belirliyor (loc=0-10)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(42,38))
sns.catplot(x='Country', y='Total_production', hue='Coffee type', data=df)
plt.xticks(rotation=90);

# %%
sns.countplot(df['Coffee type'])
plt.title("Total Transaction")
plt.xticks(rotation=90);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,18))
sns.countplot(df['1992/93'])
plt.title("Total 1992-93 years Transaction")
plt.xticks(rotation=90);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,8))
explode=[0.1,0,0] #en büyük dilimi ayırmak için
df['Coffee type'].value_counts().plot.pie(autopct='%1.1f%%') 
#yüzdeleri dilimlerin içine yazdırmak için(autopct='%1.1f%%')

# %%
plt.figure(figsize=(16,16))
explode=[0.1,0,0] #en büyük dilimi ayırmak için
df['Country'].value_counts().plot.pie(autopct='%1.1f%%') 
#yüzdeleri dilimlerin içine yazdırmak için(autopct='%1.1f%%')

# %%
plt.figure(figsize=(12,10))
sns.countplot(df['Coffee type'],hue=df.Country)
plt.xticks(rotation=90);
#hue seçilen sütunu renklendirmek için
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
plt.title("Total Montly Transaction")
sns.countplot(df['Country'],hue=df['Coffee type'])
plt.xticks(rotation=90);
#hue seçilen sütunu renklendirmek için
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['Country'],y=df.index,palette='hot')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Total_production'])#en fazla alışveriş yapanların grafiğini çizer

# %%
plt.figure(figsize=(8,6))
sns.boxplot(y="2019/20",x="Coffee type",data=df)

# %%
plt.figure(figsize=(12,6))
sns.distplot(df['1997/98']); #dağılımına bakmak için #satış

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['Total_production']); #dağılımına bakmak için #satış
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(12,6))
sns.lineplot(y="2016/17", x='Country',data=df)
plt.xticks(rotation=90);
